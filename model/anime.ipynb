# %%
# !cd /Users/jason/.kaggle/ && ls

# %%
# !kaggle datasets download -d irahhhhhh/anime-dataset-for-anime-recommender-system

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
anime_data = pd.read_csv('data/anime_data.csv')
anime_data.head(3)
# Out:
#     code  score                                          image_url  \
# 0   5114   9.22  https://cdn.myanimelist.net/images/anime/1223/...
# 1  38524   9.07  https://cdn.myanimelist.net/images/anime/1517/...
# 2  35180   9.01  https://cdn.myanimelist.net/images/anime/3/884...
#
#                                             synopsis  \
# 0  "In order for something to be obtained, someth...
# 1  Seeking to restore humanity’s diminishing hope...
# 2  Now in his second year of high school, Rei Kir...
#
#                                          show_titles  popularity  members  \
# 0  Fullmetal Alchemist: Brotherhood;;Hagane no Re...           4  2039883
# 1                 Shingeki no Kyojin Season 3 Part 2          81   829239
# 2  3-gatsu no Lion 2nd Season;;Sangatsu no Lion S...         558   239997
#
#    scored_by type                          rating    premiered     studios  \
# 0    1238537   TV  R - 17+ (violence & profanity)  Spring 2009       Bones
# 1     528877   TV  R - 17+ (violence & profanity)  Spring 2019  Wit Studio
# 2     113998   TV       PG-13 - Teens 13 or older    Fall 2017       Shaft
#
#                                               genres
# 0  action;military;adventure;comedy;drama;magic;f...
# 1  action;military;mystery;super power;drama;fant...
# 2                    drama;game;seinen;slice of life

# %%
anime_data.describe()
# Out:
#                code        score    popularity       members     scored_by
# count   4022.000000  4022.000000   4022.000000  4.022000e+03  4.022000e+03
# mean   15753.460965     7.279935   3556.939582  1.141317e+05  5.775176e+04
# std    14806.742677     0.534278   2906.829233  2.155543e+05  1.264987e+05
# min        1.000000     6.460000      1.000000  3.750000e+02  1.100000e+02
# 25%     2158.250000     6.840000   1136.250000  7.249750e+03  2.478250e+03
# 50%     9928.500000     7.210000   2757.500000  3.258050e+04  1.282850e+04
# 75%    32206.250000     7.610000   5438.750000  1.219290e+05  5.306550e+04
# max    44050.000000     9.220000  12609.000000  2.348928e+06  1.599170e+06

# %%
anime_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4022 entries, 0 to 4021
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   code         4022 non-null   int64
#  1   score        4022 non-null   float64
#  2   image_url    4022 non-null   object
#  3   synopsis     4022 non-null   object
#  4   show_titles  4022 non-null   object
#  5   popularity   4022 non-null   int64
#  6   members      4022 non-null   int64
#  7   scored_by    4022 non-null   int64
#  8   type         4022 non-null   object
#  9   rating       3984 non-null   object
#  10  premiered    4022 non-null   object
#  11  studios      3809 non-null   object
#  12  genres       4022 non-null   object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 408.6+ KB

# %%
anime_data.isnull().sum()
# Out:
# code             0
# score            0
# image_url        0
# synopsis         0
# show_titles      0
# popularity       0
# members          0
# scored_by        0
# type             0
# rating          38
# premiered        0
# studios        213
# genres           0
# dtype: int64

# %%
anime_data['rating'] = anime_data['rating'].fillna(anime_data['rating'].mode()[0])

anime_data['rating'].value_counts()
# Out:
# rating
# PG-13 - Teens 13 or older         2333
# R - 17+ (violence & profanity)     565
# G - All Ages                       542
# PG - Children                      347
# R+ - Mild Nudity                   235
# Name: count, dtype: int64

# %%
anime_data.isnull().sum()
# Out:
# code             0
# score            0
# image_url        0
# synopsis         0
# show_titles      0
# popularity       0
# members          0
# scored_by        0
# type             0
# rating           0
# premiered        0
# studios        213
# genres           0
# dtype: int64

# %%
anime_data.columns
# Out:
# Index(['code', 'score', 'image_url', 'synopsis', 'show_titles', 'popularity',
#        'members', 'scored_by', 'type', 'rating', 'premiered', 'studios',
#        'genres'],
#       dtype='object')

# %%
anime_data['synopsis_genres'] = anime_data['synopsis'] + ' ' + anime_data['genres']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
anime_data['synopsis_genres'].shape
# Out:
# (4022,)

# %%
# Sample small selection of data

anime_data_sample = anime_data.sample(frac=0.4, random_state=42)

print(anime_data.shape)
print(anime_data_sample.shape)
# Out:
# (4022, 14)
# (1609, 14)

# %%
vectorizer = TfidfVectorizer()

X_transformed = vectorizer.fit_transform(anime_data_sample['synopsis_genres'])

print(X_transformed)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 130109 stored elements and shape (1609, 17113)>
#   Coords	Values
#   (0, 3775)	0.08102939240173945
#   (0, 2891)	0.13508792015477114
#   (0, 636)	0.05365132601048398
#   (0, 15123)	0.14129761922910586
#   (0, 14918)	0.13103796089725378
#   (0, 5924)	0.10167743220034475
#   (0, 15262)	0.07882283018190675
#   (0, 15135)	0.05810256828265808
#   (0, 533)	0.14643503127167637
#   (0, 10672)	0.15048499052919376
#   (0, 6042)	0.15048499052919376
#   (0, 14897)	0.14643503127167637
#   (0, 3640)	0.15544174006167827
#   (0, 8048)	0.15048499052919376
#   (0, 13059)	0.16183210164609899
#   (0, 14478)	0.14643503127167637
#   (0, 10155)	0.14301083950962085
#   (0, 766)	0.025493069992791374
#   (0, 10795)	0.1288011336711451
#   (0, 9408)	0.08555199240636743
#   (0, 10576)	0.14549504762119977
#   (0, 2619)	0.18007220238348262
#   (0, 1002)	0.09110597129470056
#   (0, 14637)	0.13103796089725378
#   (0, 5270)	0.06979950201634738
#   :	:
#   (1608, 16621)	0.08022746322436008
#   (1608, 4170)	0.08620841528963767
#   (1608, 3102)	0.08904799098871873
#   (1608, 3665)	0.09270884077435775
#   (1608, 2508)	0.09270884077435775
#   (1608, 12594)	0.08904799098871873
#   (1608, 15114)	0.08620841528963767
#   (1608, 15984)	0.09270884077435775
#   (1608, 10702)	0.08904799098871873
#   (1608, 12712)	0.370835363097431
#   (1608, 10610)	0.09270884077435775
#   (1608, 8523)	0.2781265223230732
#   (1608, 12678)	0.1854176815487155
#   (1608, 9849)	0.09270884077435775
#   (1608, 1114)	0.09270884077435775
#   (1608, 2564)	0.09786851875307738
#   (1608, 14742)	0.09786851875307738
#   (1608, 2111)	0.19573703750615476
#   (1608, 14063)	0.09786851875307738
#   (1608, 1460)	0.09786851875307738
#   (1608, 15573)	0.09786851875307738
#   (1608, 10565)	0.09786851875307738
#   (1608, 16247)	0.09786851875307738
#   (1608, 11228)	0.09786851875307738
#   (1608, 7411)	0.09786851875307738

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_sim = cosine_similarity(X_transformed, X_transformed)

cosine_sim_df = pd.DataFrame(cosine_sim, index=anime_data_sample['synopsis'], columns=anime_data_sample['synopsis'])

print(cosine_sim_df)
# Out:
# synopsis                                            Despite completing all the tasks given to them, Ainz Ooal Gown, Tanya Degurechaff, Kazuma Satou, Subaru Natsuki, and the other members of Class 2 are surprised to find out that their role as students is far from over. With no means of returning home, the class of eccentric personalities is still mysteriously stuck in the unfamiliar world. Although, as they are becoming quite fond of each other, spending more time together does not sound that bad. With the unexpected arrival of new transfer students, the comedic antics of our beloved characters continue to grow. Thus, their bizarre yet nonchalant school life continues. [Written by MAL Rewrite]  \
# synopsis
# Despite completing all the tasks given to them,...                                           1.000000
# In a world plagued by magical dangers and threa...                                           0.116407
# The sequel to Cencoroll.                                                                     0.022394
# Midori Asakusa sees the world a bit differently...                                           0.077266
# In this sequel, a girl named Kazusano Kazuki jo...                                           0.035939
# ...                                                                                               ...
# Leo the white lion was born on an ocean liner t...                                           0.066776
# After mustering up the courage to propose to a ...                                           0.096387
# Third season of Miss Monochrome: The Animation.                                              0.044587
# Off-duty Japan Self-Defense Forces (JSDF) offic...                                           0.097595
# Within Thailand is Roanapur, a depraved, crime-...                                           0.059166
#
# synopsis                                            In a world plagued by magical dangers and threats, there exist special warriors—known as Inquisitors—who are tasked with non-violently preventing these threats and nefarious actions. The Anti-Magic Academy is a specialized school built to educate and train these Inquisitors, which splits its students into small squads in order to train them to work together. Among these talented squads is the 35th Test Platoon, also known as the "Small Fry Platoon" due to its low ranking and incompetent members. However, everything changes when Ouka Ootori, a powerful yet rebellious former Inquisitor, is forced into joining due to her tendency to break rules and committing a serious violation: the killing of a witch. Tempers flare upon her arrival, as she clashes with their clumsy captain Takeru Kusanagi and argues with the rest of the squad over her views on witches. This eclectic group has a long way to go if they wish to succeed and climb the ranks at the Anti-Magic Academy: they must first set aside their differences and come to work together as a team. [Written by MAL Rewrite]  \
# synopsis
# Despite completing all the tasks given to them,...                                           0.116407
# In a world plagued by magical dangers and threa...                                           1.000000
# The sequel to Cencoroll.                                                                     0.034403
# Midori Asakusa sees the world a bit differently...                                           0.085637
# In this sequel, a girl named Kazusano Kazuki jo...                                           0.065791
# ...                                                                                               ...
# Leo the white lion was born on an ocean liner t...                                           0.070835
# After mustering up the courage to propose to a ...                                           0.081188
# Third season of Miss Monochrome: The Animation.                                              0.014014
# Off-duty Japan Self-Defense Forces (JSDF) offic...                                           0.151878
# Within Thailand is Roanapur, a depraved, crime-...                                           0.093585
#
# synopsis                                            The sequel to Cencoroll.  \
# synopsis
# Despite completing all the tasks given to them,...                  0.022394
# In a world plagued by magical dangers and threa...                  0.034403
# The sequel to Cencoroll.                                            1.000000
# Midori Asakusa sees the world a bit differently...                  0.023180
# In this sequel, a girl named Kazusano Kazuki jo...                  0.127467
# ...                                                                      ...
# Leo the white lion was born on an ocean liner t...                  0.023341
# After mustering up the courage to propose to a ...                  0.018994
# Third season of Miss Monochrome: The Animation.                     0.007195
# Off-duty Japan Self-Defense Forces (JSDF) offic...                  0.033830
# Within Thailand is Roanapur, a depraved, crime-...                  0.026902
#
# synopsis                                            Midori Asakusa sees the world a bit differently. Always having her nose in a sketchbook, Asakusa draws detailed landscapes and backgrounds of both the world around her and the one within her boundless imagination. Even the simple act of doodling on a wall evolves into an emergency repair on the outer hull of her spaceship. She is only brought back to reality by her best friend Sayaka Kanamori. The pair are stark opposites, with Asakusa's childlike wonder contrasted by Kanamori's calculated approach to life. After a chance encounter where the two "save" the young model Tsubame Misuzaki from her overprotective bodyguard, a connection instantly sparks between Asakusa and Misuzaki, as both share an intense passion for art and animation. Whereas Asakusa is interested in backgrounds and settings, Misuzaki loves drawing the human form. Sensing a money-making opportunity, Kanamori suggests that they start an animation club, which they disguise as a motion picture club since the school already has an anime club. Thus begins the trio's journey of producing animation that will awe the world. From the brilliant mind of Masaaki Yuasa, Eizouken ni wa Te wo Dasu na! is a love letter to animation, wildly creative in its approach, and a testament to the potential of the medium. [Written by MAL Rewrite]  \
# synopsis
# Despite completing all the tasks given to them,...                                           0.077266
# In a world plagued by magical dangers and threa...                                           0.085637
# The sequel to Cencoroll.                                                                     0.023180
# Midori Asakusa sees the world a bit differently...                                           1.000000
# In this sequel, a girl named Kazusano Kazuki jo...                                           0.026240
# ...                                                                                               ...
# Leo the white lion was born on an ocean liner t...                                           0.083399
# After mustering up the courage to propose to a ...                                           0.079537
# Third season of Miss Monochrome: The Animation.                                              0.119115
# Off-duty Japan Self-Defense Forces (JSDF) offic...                                           0.091862
# Within Thailand is Roanapur, a depraved, crime-...                                           0.070098
#
# synopsis                                            In this sequel, a girl named Kazusano Kazuki joins up with the 6 girls and Ikko. With Kazuki around, Ikko will find himself in more embarrassing situations with these priestesses-in-training. (Source: ANN)  \
# synopsis
# Despite completing all the tasks given to them,...                                           0.035939
# In a world plagued by magical dangers and threa...                                           0.065791
# The sequel to Cencoroll.                                                                     0.127467
# Midori Asakusa sees the world a bit differently...                                           0.026240
# In this sequel, a girl named Kazusano Kazuki jo...                                           1.000000
# ...                                                                                               ...
# Leo the white lion was born on an ocean liner t...                                           0.025411
# After mustering up the courage to propose to a ...                                           0.062923
# Third season of Miss Monochrome: The Animation.                                              0.010409
# Off-duty Japan Self-Defense Forces (JSDF) offic...                                           0.059134
# Within Thailand is Roanapur, a depraved, crime-...                                           0.023161
#
# synopsis                                            There are some things that people are unable to say while they are alive; for these, there are "shigofumi," letters carried from the world of the dead to the world of the living. When a person with strong emotions dies, they are able to create a shigofumi, whether their feelings are of love, longing, or resentment. It is the quiet and mysterious Fumika's job to deliver these messages from the departed. Along with her talking magic staff Kanaka, she ensures that each shigofumi reaches its intended recipient, even if that person does not want to face its contents. Fumika witnesses the tragedies of people, both dead and alive, and sees their deepest secrets revealed. What is unclear, however, are the details of Fumika's past. Who was she before she came to be a carrier of shigofumi? [Written by MAL Rewrite]  \
# synopsis
# ...
# synopsis
# Despite completing all the tasks given to them,...                                           0.059166
# In a world plagued by magical dangers and threa...                                           0.093585
# The sequel to Cencoroll.                                                                     0.026902
# Midori Asakusa sees the world a bit differently...                                           0.070098
# In this sequel, a girl named Kazusano Kazuki jo...                                           0.023161
# ...                                                                                               ...
# Leo the white lion was born on an ocean liner t...                                           0.104828
# After mustering up the courage to propose to a ...                                           0.069058
# Third season of Miss Monochrome: The Animation.                                              0.019403
# Off-duty Japan Self-Defense Forces (JSDF) offic...                                           0.084225
# Within Thailand is Roanapur, a depraved, crime-...                                           1.000000
#
# [1609 rows x 1609 columns]

# %%
np.save('cosine_sim.npy', cosine_sim)
