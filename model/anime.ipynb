# %%
# !cd /Users/jason/.kaggle/ && ls

# %%
# !kaggle datasets download -d irahhhhhh/anime-dataset-for-anime-recommender-system

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
anime_data = pd.read_csv('data/anime_data.csv')
anime_data.head(3)
# Out:
#     code  score                                          image_url  \
# 0   5114   9.22  https://cdn.myanimelist.net/images/anime/1223/...
# 1  38524   9.07  https://cdn.myanimelist.net/images/anime/1517/...
# 2  35180   9.01  https://cdn.myanimelist.net/images/anime/3/884...
#
#                                             synopsis  \
# 0  "In order for something to be obtained, someth...
# 1  Seeking to restore humanity’s diminishing hope...
# 2  Now in his second year of high school, Rei Kir...
#
#                                          show_titles  popularity  members  \
# 0  Fullmetal Alchemist: Brotherhood;;Hagane no Re...           4  2039883
# 1                 Shingeki no Kyojin Season 3 Part 2          81   829239
# 2  3-gatsu no Lion 2nd Season;;Sangatsu no Lion S...         558   239997
#
#    scored_by type                          rating    premiered     studios  \
# 0    1238537   TV  R - 17+ (violence & profanity)  Spring 2009       Bones
# 1     528877   TV  R - 17+ (violence & profanity)  Spring 2019  Wit Studio
# 2     113998   TV       PG-13 - Teens 13 or older    Fall 2017       Shaft
#
#                                               genres
# 0  action;military;adventure;comedy;drama;magic;f...
# 1  action;military;mystery;super power;drama;fant...
# 2                    drama;game;seinen;slice of life

# %%
anime_data.describe()
# Out:
#                code        score    popularity       members     scored_by
# count   4022.000000  4022.000000   4022.000000  4.022000e+03  4.022000e+03
# mean   15753.460965     7.279935   3556.939582  1.141317e+05  5.775176e+04
# std    14806.742677     0.534278   2906.829233  2.155543e+05  1.264987e+05
# min        1.000000     6.460000      1.000000  3.750000e+02  1.100000e+02
# 25%     2158.250000     6.840000   1136.250000  7.249750e+03  2.478250e+03
# 50%     9928.500000     7.210000   2757.500000  3.258050e+04  1.282850e+04
# 75%    32206.250000     7.610000   5438.750000  1.219290e+05  5.306550e+04
# max    44050.000000     9.220000  12609.000000  2.348928e+06  1.599170e+06

# %%
anime_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4022 entries, 0 to 4021
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   code         4022 non-null   int64
#  1   score        4022 non-null   float64
#  2   image_url    4022 non-null   object
#  3   synopsis     4022 non-null   object
#  4   show_titles  4022 non-null   object
#  5   popularity   4022 non-null   int64
#  6   members      4022 non-null   int64
#  7   scored_by    4022 non-null   int64
#  8   type         4022 non-null   object
#  9   rating       3984 non-null   object
#  10  premiered    4022 non-null   object
#  11  studios      3809 non-null   object
#  12  genres       4022 non-null   object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 408.6+ KB

# %%
anime_data.isnull().sum()
# Out:
# code             0
# score            0
# image_url        0
# synopsis         0
# show_titles      0
# popularity       0
# members          0
# scored_by        0
# type             0
# rating          38
# premiered        0
# studios        213
# genres           0
# dtype: int64

# %%
anime_data['rating'] = anime_data['rating'].fillna(anime_data['rating'].mode()[0])

anime_data['rating'].value_counts()
# Out:
# rating
# PG-13 - Teens 13 or older         2333
# R - 17+ (violence & profanity)     565
# G - All Ages                       542
# PG - Children                      347
# R+ - Mild Nudity                   235
# Name: count, dtype: int64

# %%
anime_data.isnull().sum()
# Out:
# code             0
# score            0
# image_url        0
# synopsis         0
# show_titles      0
# popularity       0
# members          0
# scored_by        0
# type             0
# rating           0
# premiered        0
# studios        213
# genres           0
# dtype: int64

# %%
anime_data.columns
# Out:
# Index(['code', 'score', 'image_url', 'synopsis', 'show_titles', 'popularity',
#        'members', 'scored_by', 'type', 'rating', 'premiered', 'studios',
#        'genres'],
#       dtype='object')

# %%
anime_data['synopsis_genres'] = anime_data['synopsis'] + ' ' + anime_data['genres']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
anime_data['synopsis_genres'].shape
# Out:
# (4022,)

# %%
# Sample small selection of data

anime_data_sample = anime_data.sample(frac=0.55, random_state=42)

print(anime_data.shape)
print(anime_data_sample.shape)
# Out:
# (4022, 14)
# (2212, 14)

# %%
vectorizer = TfidfVectorizer()

X_transformed = vectorizer.fit_transform(anime_data_sample['synopsis_genres'])

print(X_transformed)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 178621 stored elements and shape (2212, 20246)>
#   Coords	Values
#   (0, 4430)	0.08066797449967542
#   (0, 3410)	0.13579020055874205
#   (0, 751)	0.053458573652472904
#   (0, 17900)	0.1416236493823075
#   (0, 17665)	0.1341504934908411
#   (0, 6951)	0.10232279746989988
#   (0, 18063)	0.07852186230806824
#   (0, 17912)	0.058323842312583356
#   (0, 625)	0.15289773821928124
#   (0, 12582)	0.1569317704106578
#   (0, 7087)	0.1569317704106578
#   (0, 17641)	0.15289773821928124
#   (0, 4268)	0.16186902678959994
#   (0, 9447)	0.1465325076806679
#   (0, 15448)	0.16186902678959994
#   (0, 17122)	0.1375612191103492
#   (0, 11973)	0.14159525130172576
#   (0, 909)	0.025430254877623768
#   (0, 12725)	0.12832971527613662
#   (0, 11074)	0.08661440540461095
#   (0, 12456)	0.14480396304501522
#   (0, 3103)	0.18264475117195028
#   (0, 1181)	0.09219275068119488
#   (0, 17325)	0.13262396273140709
#   (0, 6170)	0.0693373196342507
#   :	:
#   (2211, 3192)	0.09820491145866633
#   (2211, 16777)	0.09094628241592555
#   (2211, 12530)	0.12010238388465046
#   (2211, 15612)	0.10671873171467705
#   (2211, 3943)	0.10460951157355446
#   (2211, 2146)	0.09694058186652513
#   (2211, 13690)	0.09013606957008959
#   (2211, 7460)	0.09694058186652513
#   (2211, 10993)	0.10671873171467705
#   (2211, 12692)	0.09957931597318673
#   (2211, 18650)	0.22406708399214742
#   (2211, 18054)	0.11555824778654653
#   (2211, 9433)	0.11203354199607371
#   (2211, 13558)	0.11203354199607371
#   (2211, 4317)	0.11555824778654653
#   (2211, 5616)	0.12010238388465046
#   (2211, 1014)	0.12010238388465046
#   (2211, 10779)	0.12010238388465046
#   (2211, 12823)	0.12650698399953858
#   (2211, 3678)	0.12650698399953858
#   (2211, 10947)	0.12650698399953858
#   (2211, 2145)	0.12650698399953858
#   (2211, 3186)	0.12650698399953858
#   (2211, 1685)	0.12650698399953858
#   (2211, 19771)	0.12650698399953858

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_sim = cosine_similarity(X_transformed, X_transformed)

cosine_sim_df = pd.DataFrame(cosine_sim, index=anime_data_sample['synopsis_genres'], columns=anime_data_sample['synopsis_genres'])

print(cosine_sim_df)
# Out:
# synopsis_genres                                     Despite completing all the tasks given to them, Ainz Ooal Gown, Tanya Degurechaff, Kazuma Satou, Subaru Natsuki, and the other members of Class 2 are surprised to find out that their role as students is far from over. With no means of returning home, the class of eccentric personalities is still mysteriously stuck in the unfamiliar world. Although, as they are becoming quite fond of each other, spending more time together does not sound that bad. With the unexpected arrival of new transfer students, the comedic antics of our beloved characters continue to grow. Thus, their bizarre yet nonchalant school life continues. [Written by MAL Rewrite] comedy;parody;fantasy  \
# synopsis_genres
# Despite completing all the tasks given to them,...                                           1.000000
# In a world plagued by magical dangers and threa...                                           0.114501
# The sequel to Cencoroll. action;sci-fi                                                       0.022297
# Midori Asakusa sees the world a bit differently...                                           0.075283
# In this sequel, a girl named Kazusano Kazuki jo...                                           0.035491
# ...                                                                                               ...
# In the fourth movie, the classical Japan-Europe...                                           0.062756
# From standing in the sun for hours to traveling...                                           0.056033
# Second out of three compilation movies for the ...                                           0.026703
# With broken spirits and enigmatic questions tha...                                           0.077003
# Atop a hill overlooking a seaside port sits a b...                                           0.097666
#
# synopsis_genres                                     In a world plagued by magical dangers and threats, there exist special warriors—known as Inquisitors—who are tasked with non-violently preventing these threats and nefarious actions. The Anti-Magic Academy is a specialized school built to educate and train these Inquisitors, which splits its students into small squads in order to train them to work together. Among these talented squads is the 35th Test Platoon, also known as the "Small Fry Platoon" due to its low ranking and incompetent members. However, everything changes when Ouka Ootori, a powerful yet rebellious former Inquisitor, is forced into joining due to her tendency to break rules and committing a serious violation: the killing of a witch. Tempers flare upon her arrival, as she clashes with their clumsy captain Takeru Kusanagi and argues with the rest of the squad over her views on witches. This eclectic group has a long way to go if they wish to succeed and climb the ranks at the Anti-Magic Academy: they must first set aside their differences and come to work together as a team. [Written by MAL Rewrite] action;ecchi;fantasy;harem;military;romance;supernatural  \
# synopsis_genres
# Despite completing all the tasks given to them,...                                           0.114501
# In a world plagued by magical dangers and threa...                                           1.000000
# The sequel to Cencoroll. action;sci-fi                                                       0.033695
# Midori Asakusa sees the world a bit differently...                                           0.083030
# In this sequel, a girl named Kazusano Kazuki jo...                                           0.063464
# ...                                                                                               ...
# In the fourth movie, the classical Japan-Europe...                                           0.060939
# From standing in the sun for hours to traveling...                                           0.068726
# Second out of three compilation movies for the ...                                           0.025144
# With broken spirits and enigmatic questions tha...                                           0.067743
# Atop a hill overlooking a seaside port sits a b...                                           0.116437
#
# synopsis_genres                                     The sequel to Cencoroll. action;sci-fi  \
# synopsis_genres
# Despite completing all the tasks given to them,...                                0.022297
# In a world plagued by magical dangers and threa...                                0.033695
# The sequel to Cencoroll. action;sci-fi                                            1.000000
# Midori Asakusa sees the world a bit differently...                                0.022639
# In this sequel, a girl named Kazusano Kazuki jo...                                0.115207
# ...                                                                                    ...
# In the fourth movie, the classical Japan-Europe...                                0.026333
# From standing in the sun for hours to traveling...                                0.014264
# Second out of three compilation movies for the ...                                0.071726
# With broken spirits and enigmatic questions tha...                                0.019456
# Atop a hill overlooking a seaside port sits a b...                                0.026907
#
# synopsis_genres                                     Midori Asakusa sees the world a bit differently. Always having her nose in a sketchbook, Asakusa draws detailed landscapes and backgrounds of both the world around her and the one within her boundless imagination. Even the simple act of doodling on a wall evolves into an emergency repair on the outer hull of her spaceship. She is only brought back to reality by her best friend Sayaka Kanamori. The pair are stark opposites, with Asakusa's childlike wonder contrasted by Kanamori's calculated approach to life. After a chance encounter where the two "save" the young model Tsubame Misuzaki from her overprotective bodyguard, a connection instantly sparks between Asakusa and Misuzaki, as both share an intense passion for art and animation. Whereas Asakusa is interested in backgrounds and settings, Misuzaki loves drawing the human form. Sensing a money-making opportunity, Kanamori suggests that they start an animation club, which they disguise as a motion picture club since the school already has an anime club. Thus begins the trio's journey of producing animation that will awe the world. From the brilliant mind of Masaaki Yuasa, Eizouken ni wa Te wo Dasu na! is a love letter to animation, wildly creative in its approach, and a testament to the potential of the medium. [Written by MAL Rewrite] adventure;comedy;school;seinen  \
# synopsis_genres
# Despite completing all the tasks given to them,...                                           0.075283
# In a world plagued by magical dangers and threa...                                           0.083030
# The sequel to Cencoroll. action;sci-fi                                                       0.022639
# Midori Asakusa sees the world a bit differently...                                           1.000000
# In this sequel, a girl named Kazusano Kazuki jo...                                           0.025350
# ...                                                                                               ...
# In the fourth movie, the classical Japan-Europe...                                           0.047884
# From standing in the sun for hours to traveling...                                           0.062305
# Second out of three compilation movies for the ...                                           0.017205
# With broken spirits and enigmatic questions tha...                                           0.045804
# Atop a hill overlooking a seaside port sits a b...                                           0.099804
#
# synopsis_genres                                     In this sequel, a girl named Kazusano Kazuki joins up with the 6 girls and Ikko. With Kazuki around, Ikko will find himself in more embarrassing situations with these priestesses-in-training. (Source: ANN) comedy;ecchi;harem;romance;supernatural  \
# synopsis_genres
# Despite completing all the tasks given to them,...                                           0.035491
# In a world plagued by magical dangers and threa...                                           0.063464
# The sequel to Cencoroll. action;sci-fi                                                       0.115207
# Midori Asakusa sees the world a bit differently...                                           0.025350
# In this sequel, a girl named Kazusano Kazuki jo...                                           1.000000
# ...                                                                                               ...
# In the fourth movie, the classical Japan-Europe...                                           0.053189
# From standing in the sun for hours to traveling...                                           0.019206
# Second out of three compilation movies for the ...                                           0.022033
# With broken spirits and enigmatic questions tha...                                           0.043285
# ...
# With broken spirits and enigmatic questions tha...                                           1.000000
# Atop a hill overlooking a seaside port sits a b...                                           0.058551
#
# synopsis_genres                                     Atop a hill overlooking a seaside port sits a boarding house named Coquelicot Manor. Since the building is run by her family, Umi Matsuzaki carries out many of the duties involved in managing the small establishment, such as preparing meals for her fellow boarders. When she isn't at home, she is a student at the local high school—one that is currently dealing with a small crisis. In anticipation of the upcoming Olympic Games, a beloved old clubhouse is set to be demolished to make way for a modern building. As a result, a large part of the student body has banded together, working tirelessly to prevent this from happening. Umi finds herself helping the newspaper club to spread information about this cause where she befriends Shun Kazama, whom she gradually begins to fall in love with. But Shun is an orphan who doesn't know much about his origins, and when the two begin searching for clues to the boy's past, they discover that they may have a lot more in common than either of them could have thought. [Writtten by MAL Rewrite] historical;romance;school;shoujo
# synopsis_genres
# Despite completing all the tasks given to them,...                                           0.097666
# In a world plagued by magical dangers and threa...                                           0.116437
# The sequel to Cencoroll. action;sci-fi                                                       0.026907
# Midori Asakusa sees the world a bit differently...                                           0.099804
# In this sequel, a girl named Kazusano Kazuki jo...                                           0.042795
# ...                                                                                               ...
# In the fourth movie, the classical Japan-Europe...                                           0.064278
# From standing in the sun for hours to traveling...                                           0.089950
# Second out of three compilation movies for the ...                                           0.034317
# With broken spirits and enigmatic questions tha...                                           0.058551
# Atop a hill overlooking a seaside port sits a b...                                           1.000000
#
# [2212 rows x 2212 columns]

# %%
np.save('cosine_sim.npy', cosine_sim)
